# %% [raw]
# import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/test01/test1 - Sheet1.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/3980011271.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('/kaggle/input/test01/test1 - Sheet1.csv')
#
# NameError: name 'pd' is not defined

# %%
df
